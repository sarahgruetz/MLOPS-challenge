# %%
import requests

# %%
# Check Helth
resp = requests.get('http://localhost:80')

resp.json()
# Out:
# {'Simple Model': '1.0'}

# %%
from sklearn import datasets
digits = datasets.load_digits().data

# %%
# Input parameters
param = {'digit_image':digits[16].tolist()}


resp = requests.post('http://localhost:80/single_predict', json = param)
print(f'Request Status: {resp.status_code}')
resp.json()
# Out:
# Request Status: 200
# {'digit_value': 6}
